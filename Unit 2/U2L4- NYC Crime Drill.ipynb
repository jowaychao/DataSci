# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import style
from sklearn import linear_model
import warnings
warnings.filterwarnings(action='ignore', module='scipy', message='^internalgelsd')
pd.options.display.float_format='{:.3f}'.format
# %matplotlib inline

# %%
data_path = 'file:///C:/Users/JChaotogo/Desktop/New%20folder/nycrimedata.xls'
df = pd.read_excel(data_path)
df.columns = ['city', 'population', 'violentcrime', 'murder', 'raperevised', 'rapelegacy', 'robbery', 'assault', 'propertycrime', 'burglary', 'larceny', 'motortheft', 'arson']

df.head(20)
df.drop(df.index[[0, 1, 2, 3]], inplace=True)
df
# Out:
#                                                   city population  \
# 4                                        Adams Village       1861
# 5                             Addison Town and Village       2577
# 6                                        Akron Village       2846
# 7                                               Albany      97956
# 8                                       Albion Village       6388
# 9                                       Alfred Village       4089
# 10                                    Allegany Village       1781
# 11                                        Amherst Town     118296
# 12                                  Amityville Village       9519
# 13                                           Amsterdam      18182
# 14                                      Arcade Village       2053
# 15                                     Ardsley Village       4523
# 16                                   Asharoken Village        658
# ...

# %%
df.drop(columns='raperevised')
# Out:
#                                                   city population  \
# 4                                        Adams Village       1861
# 5                             Addison Town and Village       2577
# 6                                        Akron Village       2846
# 7                                               Albany      97956
# 8                                       Albion Village       6388
# 9                                       Alfred Village       4089
# 10                                    Allegany Village       1781
# 11                                        Amherst Town     118296
# 12                                  Amityville Village       9519
# 13                                           Amsterdam      18182
# 14                                      Arcade Village       2053
# 15                                     Ardsley Village       4523
# 16                                   Asharoken Village        658
# ...

# %%
#create categorical features for population^2, murder, and robbery
for entry in (df.murder)|(df.robbery):
    if entry>0:
        entry = 1
    else:
        entry = 0
df['murder'] = np.where((df['murder']>0), 1, 0)
df['robbery'] = np.where((df['robbery']>0), 1, 0)
df['populationsquared'] = (df['population']*df['population'])
df
# Out:
#                                                   city population  \
# 4                                        Adams Village       1861
# 5                             Addison Town and Village       2577
# 6                                        Akron Village       2846
# 7                                               Albany      97956
# 8                                       Albion Village       6388
# 9                                       Alfred Village       4089
# 10                                    Allegany Village       1781
# 11                                        Amherst Town     118296
# 12                                  Amityville Village       9519
# 13                                           Amsterdam      18182
# 14                                      Arcade Village       2053
# 15                                     Ardsley Village       4523
# 16                                   Asharoken Village        658
# ...
